# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import os
import re
import tensorflow
import math
import csv
from os import listdir
from os.path import isfile, join
from numpy import dot
from numpy.linalg import norm
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import PCA
from sklearn.preprocessing import binarize
from sklearn import preprocessing, metrics, decomposition, pipeline, dummy
from sklearn.datasets import fetch_20newsgroups
from sklearn.metrics.pairwise import cosine_similarity
from os import listdir
from os.path import isfile, join
from gensim.models.word2vec import Word2Vec

# %%
Path = './Keywords/'
dfpest = pd.read_excel(Path+'02pest.list.xlsx', header=None)
dfchem = pd.read_excel(Path+'02chem.list.xlsx', header=None)
dfcrop = pd.read_excel(Path+'02crop.list.xlsx', header=None)


dftotal = pd.concat([dfpest, dfchem, dfcrop], ignore_index=True)
dftotal.insert(len(dftotal.columns), 'nan', None)
Names = dftotal[0]
syms_dict = {}
for i in range(len(dftotal[0])):
    j = 0
    while (not pd.isnull(dftotal.iloc[i,j])):
        syms_dict[dftotal.iloc[i,j]] = dftotal.iloc[i,0]
        j += 1

# %%
train_pre = pd.read_csv('Train_data.csv')
paras = [re.sub("\'| |\[|\]", '', text).split(',') for text in train_pre['text']]
public_pre = pd.read_csv('Public_data.csv')
paras1 = [re.sub("\'| |\[|\]", '', text).split(',') for text in public_pre['text']]

# %%
vz=250
model_w2v = Word2Vec(paras+paras1, vector_size=vz, epochs=20, sg=1,min_count=0,window=10,workers=5)

# %%
def one_hot(num,Tot):
    x=[]
    for i in range(num):
        x.append(0)
    x.append(1)
    for i in range(Tot-num-1):
        x.append(0)
    return np.array(x)

# %%
def count_times(lis,ele,bol):
    if bol:
        if ele in lis:
            return 1
        else:
            return 0
    else:
        if ele in lis:
            mm=0
            for i in lis:
                if i==ele:
                    mm+=1
            return mm
        else:
            return 0

# %%
mypath="./dataTrainComplete_1/"
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

comps=[]
ordering=[]
for i in onlyfiles:
    ordering.append(np.int(i[:-4]))
for i in ordering:
    for j in ordering:
        if i!=j:
            comps.append([i,j])

Word_freq_all=[]
Word_freq_sent_all=[] # add the exist keyword in each file
Word_freq_all_w2v=[] # directly add the word2vec of every word in each file
lens=[]
for par_ in paras:
    word_count=np.zeros(len(Names))
    word_count_sent=''
    w2v=np.zeros(vz)
    
    for i in range(len(Names)):
        if Names[i] in par_:
            for j in range(count_times(par_,Names[i],True)):
                word_count+=one_hot(i,len(Names))
                word_count_sent+=(Names[i]+' ')
                w2v+=model_w2v.wv[Names[i]]
    Word_freq_all.append(word_count)
    Word_freq_sent_all.append(word_count_sent)
    Word_freq_all_w2v.append(w2v/np.sum(word_count))
    lens.append(np.sum(word_count))
# Out:
# C:\Users\Billy\anaconda3\envs\tensorflow_1\lib\site-packages\ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide

# %%
df = pd.read_csv ('TrainLabel.csv',header=None)
labels=[]
for i in range(len(df.iloc[:][0])-1):
    i+=1
    labels.append([np.int(df.iloc[i][0]),np.int(df.iloc[i][1])])
    
    
Word_freq_all=np.array(Word_freq_all)
data=Word_freq_all
data_w2v=Word_freq_all_w2v


similarity=[]
diff=[]
similarity_w2v=[]
diff_w2v=[]
group=[]
len_diff=[]
senten=[]
mins=[]

for i in range(data.shape[0]):
    sim=[]
    dif=[]
    
    sim_w2v=[]
    dif_w2v=[]
    gp=[]
    len_dif=[]
    sent=[]
    minn=[]
    for j in range(data.shape[0]):
        if i!=j:
            if (norm(data[i]) !=0 and norm(data[j])!=0):
                
                cos_sim = dot(data[i], data[j])/(norm(data[i])*norm(data[j]))
                cos_sim_w2v = dot(data_w2v[i], data_w2v[j])/(norm(data_w2v[i])*norm(data_w2v[j]))

                sim.append(cos_sim)
                sim_w2v.append(cos_sim_w2v)
                
                gp.append(dot(data[i], data[j])/np.sum(data[i]))
                dif.append(np.sum(data[i]-data[j]))
                dif_w2v.append(np.sum(data_w2v[i]-data_w2v[j]))
                len_dif.append(lens[i]-lens[j])
                minn.append(lens[i])
            else:
                sim.append(-1)
                sim_w2v.append(-1)
                gp.append(-1)
                dif.append(-1000)
                dif_w2v.append(-1000)
                len_dif.append(-1000)
                minn.append(-1)
            sent.append(Word_freq_sent_all[i]+'\n'+'\n'+Word_freq_sent_all[j])
            
    similarity.append(sim)
    diff.append(dif)
    group.append(gp)
    similarity_w2v.append(sim_w2v)
    diff_w2v.append(dif_w2v)
    len_diff.append(len_dif)
    senten.append(sent)
    mins.append(minn)
    
    
m=0
truth=[]
for j in comps:
    if j in labels:
        truth.append(1)
        m+=1
    else:
        truth.append(0)

# %%
for i in range(5):
    plt.bar(np.linspace(1,len(Word_freq_all_w2v[i]),len(Word_freq_all_w2v[i])),Word_freq_all_w2v[i])
    plt.show()

# %%
np.array(len_diff).reshape(-1).shape
np.array(mins).reshape(-1).shape
np.array(senten).reshape(-1).shape
np.shape(comps)
# Out:
# (311922, 2)

# %%
df_sim=pd.DataFrame(data={'Keys':comps,\
                          'cos_sim':np.array(similarity).reshape(-1),\
                          'dif':np.array(diff).reshape(-1),\
                          'labeled':np.array(truth),\
                          'cos_sim_w2v':np.array(similarity_w2v).reshape(-1),\
                          'dif_w2v':np.array(diff_w2v).reshape(-1),\
                          'group':np.array(group).reshape(-1),\
                          'sent':np.array(senten).reshape(-1),\
                          'min':np.array(mins).reshape(-1)})

df_lab=df_sim.loc[df_sim['labeled'] ==1]

plt.plot(np.array(df_sim['cos_sim']),np.array(df_sim['dif']),'.',alpha=0.3)
plt.xlim([-1.2,1.2])
plt.ylim([-100,100])
plt.xlabel('cos_sim',fontsize=15)
plt.ylabel('dif',fontsize=15)
plt.show()

plt.plot(np.array(df_sim['cos_sim']),np.array(df_sim['cos_sim_w2v']),'.',alpha=0.3)
plt.xlim([-1.2,1.2])
plt.ylim([-1.2,1.2])
plt.xlabel('cos_sim',fontsize=15)
plt.ylabel('cos_sim_w2v',fontsize=15)
plt.show()

plt.plot(np.array(df_sim['dif']),np.array(df_sim['dif_w2v']),'.',alpha=0.3)
plt.xlim([-100,100])
plt.ylim([-30,30])
plt.xlabel('dif',fontsize=15)
plt.ylabel('dif_w2v',fontsize=15)
plt.show()

plt.plot(np.array(df_sim['dif']),np.array(df_sim['group']),'.',alpha=0.3)
plt.xlim([-100,100])
plt.ylim([-1.2,1.2])
plt.xlabel('dif',fontsize=15)
plt.ylabel('group',fontsize=15)
plt.show()


plt.plot(np.array(df_sim['dif']),np.array(df_sim['min']),'.',alpha=0.3)
plt.xlim([-100,100])
plt.ylim([-10,100])
plt.xlabel('dif',fontsize=15)
plt.ylabel('min',fontsize=15)
plt.show()

plt.plot(np.array(df_lab['cos_sim']),np.array(df_lab['dif']),'.',alpha=0.3)
plt.xlim([-1.2,1.2])
plt.ylim([-100,100])
plt.xlabel('cos_sim',fontsize=15)
plt.ylabel('dif',fontsize=15)
plt.show()

plt.plot(np.array(df_lab['cos_sim']),np.array(df_lab['cos_sim_w2v']),'.',alpha=0.3)
plt.xlim([-1.2,1.2])
plt.ylim([-1.2,1.2])
plt.xlabel('cos_sim',fontsize=15)
plt.ylabel('cos_sim_w2v',fontsize=15)
plt.show()

plt.plot(np.array(df_lab['dif']),np.array(df_lab['dif_w2v']),'.',alpha=0.3)
plt.xlim([-100,100])
plt.ylim([-30,30])
plt.xlabel('dif',fontsize=15)
plt.ylabel('dif_w2v',fontsize=15)
plt.show()

plt.plot(np.array(df_lab['dif']),np.array(df_lab['group']),'.',alpha=0.3)
plt.xlim([-100,100])
plt.ylim([-1.2,1.2])
plt.xlabel('dif',fontsize=15)
plt.ylabel('group',fontsize=15)
plt.show()

plt.plot(np.array(df_lab['dif']),np.array(df_lab['min']),'.',alpha=0.3)
plt.xlim([-100,100])
plt.ylim([-10,100])
plt.xlabel('dif',fontsize=15)
plt.ylabel('min',fontsize=15)
plt.show()

# %%
df1=df_sim.loc[df_sim['cos_sim'] >0.3]
df2=df1.loc[(df1['dif'] <15) & (-35 < df1['dif'])]
df8=df2.loc[(df2['cos_sim_w2v'] >0.5)]
df9=df8.loc[(df8['dif_w2v'] >-8) & (df8['dif_w2v'] <8)]
df11=df9.loc[(df9['min'] >-1) & (df9['min'] <20)]
df3=df11.loc[(df11['group'] >0.2)]

X_scaled=np.array(df3[['cos_sim','dif','cos_sim_w2v','dif_w2v','group','min']])
data=np.concatenate([np.array(df3[['Keys']]),X_scaled],axis=1)



from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, np.array(df3[['labeled']]), test_size=0.33, random_state=42)

X_train1=[]
y_train1=[]

mm=0
for i in range(len(X_train)):
    if y_train[i]==1:
        mm+=1
        for j in range(14):
            X_train1.append(X_train[i,1:])
            y_train1.append(1)   
    else:
        X_train1.append(X_train[i,1:])
        y_train1.append(0)
print('mm',mm)
        
print('len/mm',len(X_train1)/mm)
        
    
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(hidden_layer_sizes=(128,128), activation='tanh',\
                    solver='adam', alpha=0.001, batch_size='auto', learning_rate='adaptive',random_state=1, max_iter=500)

clf.fit(np.array(X_train1),np.array(y_train1).reshape(-1))

from sklearn.metrics import confusion_matrix
y_pred=clf.predict(X_test[:,1:])
cf_matrix = confusion_matrix(y_test, y_pred)
print(cf_matrix)

from sklearn.model_selection import train_test_split
X_test, y_test = [data, np.array(df3[['labeled']])]

y_pred=clf.predict(X_test[:,1:])
cf_matrix = confusion_matrix(y_test, y_pred)
print(cf_matrix)

# %%
df3=df11.loc[(df11['group'] >0.2)]
df3.insert(1,'pred',y_pred)
df_sim1=df3

df_lab=df_sim1.loc[df_sim1['labeled'] ==1]
df_pred=df_sim1.loc[df_sim1['pred'] ==1]

plt.plot(np.array(df_sim1['cos_sim']),np.array(df_sim1['dif']),'.',alpha=0.3,label='all')
plt.plot(np.array(df_lab['cos_sim']),np.array(df_lab['dif']),'.',alpha=0.3,label='labeled')
plt.plot(np.array(df_pred['cos_sim']),np.array(df_pred['dif']),'.',alpha=0.3,label='predicted')
plt.xlim([0,1.2])
plt.ylim([-40,40])
plt.legend()
plt.xlabel('cos_sim',fontsize=15)
plt.ylabel('dif',fontsize=15)
plt.show()

plt.plot(np.array(df_sim1['cos_sim']),np.array(df_sim1['cos_sim_w2v']),'.',alpha=0.3,label='all')
plt.plot(np.array(df_lab['cos_sim']),np.array(df_lab['cos_sim_w2v']),'.',alpha=0.3,label='labeled')
plt.plot(np.array(df_pred['cos_sim']),np.array(df_pred['cos_sim_w2v']),'.',alpha=0.3,label='predicted')
plt.xlim([0,1.2])
plt.ylim([0.4,1.2])
plt.legend()
plt.xlabel('cos_sim',fontsize=15)
plt.ylabel('cos_sim_w2v',fontsize=15)
plt.show()

plt.plot(np.array(df_sim1['dif']),np.array(df_sim1['dif_w2v']),'.',alpha=0.3,label='all')
plt.plot(np.array(df_lab['dif']),np.array(df_lab['dif_w2v']),'.',alpha=0.3,label='labeled')
plt.plot(np.array(df_pred['dif']),np.array(df_pred['dif_w2v']),'.',alpha=0.3,label='predicted')
plt.xlim([-100,100])
plt.ylim([-10,10])
plt.legend()
plt.xlabel('dif',fontsize=15)
plt.ylabel('dif_w2v',fontsize=15)
plt.show()

plt.plot(np.array(df_sim1['dif']),np.array(df_sim1['group']),'.',alpha=0.1,label='all')
plt.plot(np.array(df_lab['dif']),np.array(df_lab['group']),'.',alpha=0.1,label='labeled')
plt.plot(np.array(df_pred['dif']),np.array(df_pred['group']),'.',alpha=0.1,label='predicted')
plt.xlim([-100,100])
plt.ylim([0,1.2])
plt.legend()
plt.xlabel('dif',fontsize=15)
plt.ylabel('group',fontsize=15)
plt.show()

plt.plot(np.array(df_sim1['dif']),np.array(df_sim1['min']),'.',alpha=0.1,label='all')
plt.plot(np.array(df_lab['dif']),np.array(df_lab['min']),'.',alpha=0.1,label='labeled')
plt.plot(np.array(df_pred['dif']),np.array(df_pred['min']),'.',alpha=0.1,label='predicted')
plt.xlim([-250,250])
plt.ylim([-10,100])
plt.legend()
plt.xlabel('dif',fontsize=15)
plt.ylabel('min',fontsize=15)
plt.show()

# %%
df_sim.loc[(df_sim['pred']==1) & (df_sim['labeled']==0)]
# Out:
#                 Keys  pred   cos_sim   dif  labeled  cos_sim_w2v   dif_w2v  \
# 818        [10, 344]     1  0.507833  -9.0        0     0.931808  0.686395
# 1120    [1000, 1010]     1  0.866025   1.0        0     0.959863  1.121970
# 1157    [1000, 1119]     1  0.471405 -14.0        0     0.748710  0.452303
# 1269    [1000, 1361]     1  0.666667  -5.0        0     0.855051  1.395936
# 1307     [1000, 188]     1  1.000000   0.0        0     1.000000  0.000000
# 1341     [1000, 279]     1  0.755929  -3.0        0     0.889216  0.307240
# 1346     [1000, 289]     1  0.866025   1.0        0     0.959863  1.121970
# 1350     [1000, 296]     1  0.750000   0.0        0     0.918104  0.918318
# 1465     [1000, 576]     1  0.755929  -3.0        0     0.898870  1.369108
# 1572     [1000, 781]     1  0.566947  -3.0        0     0.803714  1.513016
# 1587     [1000, 809]     1  0.707107   2.0        0     0.913943  3.695015
# 1630     [1000, 891]     1  0.566947  -3.0        0     0.801825  1.458955
# 1678    [1005, 1010]     1  0.866025   1.0        0     0.959863  1.121970
# 1715    [1005, 1119]     1  0.471405 -14.0        0     0.748710  0.452303
# 1827    [1005, 1361]     1  0.666667  -5.0        0     0.855051  1.395936
# 1865     [1005, 188]     1  1.000000   0.0        0     1.000000  0.000000
# 1899     [1005, 279]     1  0.755929  -3.0        0     0.889216  0.307240
# 1904     [1005, 289]     1  0.866025   1.0        0     0.959863  1.121970
# 1908     [1005, 296]     1  0.750000   0.0        0     0.918104  0.918318
# 2023     [1005, 576]     1  0.755929  -3.0        0     0.898870  1.369108
# 2130     [1005, 781]     1  0.566947  -3.0        0     0.803714  1.513016
# 2145     [1005, 809]     1  0.707107   2.0        0     0.913943  3.695015
# 2188     [1005, 891]     1  0.566947  -3.0        0     0.801825  1.458955
# 2242     [1007, 103]     1  1.000000   0.0        0     1.000000  0.000000
# 2246     [1007, 104]     1  1.000000   0.0        0     1.000000  0.000000
# 2423     [1007, 188]     1  0.866025  -1.0        0     0.958901  1.522306
# 2770     [1007, 949]     1  0.522233  -8.0        0     0.715597  2.599612
# 2826    [1010, 1103]     1  0.447214 -12.0        0     0.725066 -0.946181
# 2852    [1010, 1165]     1  0.707107  -3.0        0     0.823098  0.465945
# 2943    [1010, 1361]     1  0.577350  -6.0        0     0.820935  0.273966
# ...              ...   ...       ...   ...      ...          ...       ...
# 289443     [897, 67]     1  0.471405  -7.0        0     0.833643 -1.479488
# 289560    [897, 892]     1  1.000000   0.0        0     1.000000  0.000000
# 289563    [897, 899]     1  1.000000   0.0        0     1.000000  0.000000
# 289572    [897, 919]     1  0.534522  -5.0        0     0.834497  0.899910
# 289615   [898, 1037]     1  0.816497  -1.0        0     0.945389  0.109465
# 289796    [898, 191]     1  0.447214  -8.0        0     0.791522  1.138012
# 290001     [898, 67]     1  0.471405  -7.0        0     0.833643 -1.479488
# 290118    [898, 892]     1  1.000000   0.0        0     1.000000  0.000000
# 290121    [898, 899]     1  1.000000   0.0        0     1.000000  0.000000
# 290130    [898, 919]     1  0.534522  -5.0        0     0.834497  0.899910
# 290678    [899, 897]     1  1.000000   0.0        0     1.000000  0.000000
# 290679    [899, 898]     1  1.000000   0.0        0     1.000000  0.000000
# 290688    [899, 919]     1  0.534522  -5.0        0     0.834497  0.899910
# 296223     [921, 83]     1  0.832050  -4.0        0     0.986070 -0.367831
# 296232     [921, 85]     1  0.727607  -8.0        0     0.954943 -0.392017
# 299446    [936, 590]     1  0.875000   0.0        0     0.981150 -0.086675
# 299625    [936, 946]     1  0.707107  -1.0        0     0.964506  1.783166
# 300129     [940, 83]     1  0.832050  -4.0        0     0.986070 -0.367831
# 300138     [940, 85]     1  0.727607  -8.0        0     0.954943 -0.392017
# 301645     [95, 510]     1  0.816497  -1.0        0     0.848452 -0.918396
# 301656     [95, 542]     1  0.500000  -6.0        0     0.754639  2.394293
# 302031   [950, 1357]     1  0.774597   2.0        0     0.913387  4.089602
# 304732   [967, 1166]     1  0.717137  -3.0        0     0.947339 -1.280037
# 307943    [977, 835]     1  0.414039 -11.0        0     0.882585  2.149169
# 308567    [979, 977]     1  0.645497  -4.0        0     0.914586  0.450576
# 309701    [988, 103]     1  0.816497  -1.0        0     0.926169 -0.921802
# 309705    [988, 104]     1  0.816497  -1.0        0     0.926169 -0.921802
# 310034    [988, 561]     1  0.534522  -5.0        0     0.728753  2.446582
# 310040    [988, 576]     1  0.534522  -5.0        0     0.794189  1.969613
# 310147    [988, 781]     1  0.534522  -5.0        0     0.726484  2.113520
#
#            group                                               sent   min
# 818     0.700000  稻熱病 葉稻熱病 亞磷酸 微生物製劑 三賽唑 亞賜圃 嘉賜黴素 喜樂克拉 護粒松 水稻 \n...  10.0
# 1120    0.750000                  稻熱病 穗稻熱病 葉稻熱病 水稻 \n\n稻熱病 穗稻熱病 水稻    4.0
# 1157    1.000000  稻熱病 穗稻熱病 葉稻熱病 水稻 \n\n稻熱病 白葉枯病 穗稻熱病 葉稻熱病 紋枯病 三賽...   4.0
# 1269    1.000000  稻熱病 穗稻熱病 葉稻熱病 水稻 \n\n稻熱病 穗稻熱病 葉稻熱病 節稻熱病 嘉賜三賽唑 ...   4.0
# 1307    1.000000             稻熱病 穗稻熱病 葉稻熱病 水稻 \n\n稻熱病 穗稻熱病 葉稻熱病 水稻    4.0
# 1341    1.000000  稻熱病 穗稻熱病 葉稻熱病 水稻 \n\n稻熱病 穗稻熱病 葉稻熱病 三賽唑 嘉賜三賽唑 富...   4.0
# 1346    0.750000                  稻熱病 穗稻熱病 葉稻熱病 水稻 \n\n稻熱病 穗稻熱病 水稻    4.0
# 1350    0.750000              稻熱病 穗稻熱病 葉稻熱病 水稻 \n\n稻熱病 穗稻熱病 紋枯病 水稻    4.0
# 1465    1.000000  稻熱病 穗稻熱病 葉稻熱病 水稻 \n\n稻熱病 穗稻熱病 葉稻熱病 三賽唑 加普胺 滅大松...   4.0
# 1572    0.750000  稻熱病 穗稻熱病 葉稻熱病 水稻 \n\n稻熱病 穗稻熱病 三賽唑 嘉賜三賽唑 保米熱斯 加...   4.0
# 1587    0.500000                     稻熱病 穗稻熱病 葉稻熱病 水稻 \n\n稻熱病 穗稻熱病    4.0
# 1630    0.750000  稻熱病 穗稻熱病 葉稻熱病 水稻 \n\n褐飛蝨 斑飛蝨 稻熱病 穗稻熱病 水稻縞葉枯病 毒...   4.0
# 1678    0.750000                  稻熱病 穗稻熱病 葉稻熱病 水稻 \n\n稻熱病 穗稻熱病 水稻    4.0
# 1715    1.000000  稻熱病 穗稻熱病 葉稻熱病 水稻 \n\n稻熱病 白葉枯病 穗稻熱病 葉稻熱病 紋枯病 三賽...   4.0
# 1827    1.000000  稻熱病 穗稻熱病 葉稻熱病 水稻 \n\n稻熱病 穗稻熱病 葉稻熱病 節稻熱病 嘉賜三賽唑 ...   4.0
# 1865    1.000000             稻熱病 穗稻熱病 葉稻熱病 水稻 \n\n稻熱病 穗稻熱病 葉稻熱病 水稻    4.0
# 1899    1.000000  稻熱病 穗稻熱病 葉稻熱病 水稻 \n\n稻熱病 穗稻熱病 葉稻熱病 三賽唑 嘉賜三賽唑 富...   4.0
# 1904    0.750000                  稻熱病 穗稻熱病 葉稻熱病 水稻 \n\n稻熱病 穗稻熱病 水稻    4.0
# 1908    0.750000              稻熱病 穗稻熱病 葉稻熱病 水稻 \n\n稻熱病 穗稻熱病 紋枯病 水稻    4.0
# 2023    1.000000  稻熱病 穗稻熱病 葉稻熱病 水稻 \n\n稻熱病 穗稻熱病 葉稻熱病 三賽唑 加普胺 滅大松...   4.0
# 2130    0.750000  稻熱病 穗稻熱病 葉稻熱病 水稻 \n\n稻熱病 穗稻熱病 三賽唑 嘉賜三賽唑 保米熱斯 加...   4.0
# 2145    0.500000                     稻熱病 穗稻熱病 葉稻熱病 水稻 \n\n稻熱病 穗稻熱病    4.0
# 2188    0.750000  稻熱病 穗稻熱病 葉稻熱病 水稻 \n\n褐飛蝨 斑飛蝨 稻熱病 穗稻熱病 水稻縞葉枯病 毒...   4.0
# 2242    1.000000                       稻熱病 葉稻熱病 水稻 \n\n稻熱病 葉稻熱病 水稻    3.0
# 2246    1.000000                       稻熱病 葉稻熱病 水稻 \n\n稻熱病 葉稻熱病 水稻    3.0
# 2423    1.000000                  稻熱病 葉稻熱病 水稻 \n\n稻熱病 穗稻熱病 葉稻熱病 水稻    3.0
# 2770    1.000000  稻熱病 葉稻熱病 水稻 \n\n稻熱病 葉稻熱病 亞賜圃 嘉賜三賽唑 護粒三賽唑 撲殺培丹 ...   3.0
# 2826    1.000000  稻熱病 穗稻熱病 水稻 \n\n稻熱病 穗稻熱病 葉稻熱病 紋枯病 三賽唑 亞賜圃 嘉賜三賽...   3.0
# 2852    1.000000        稻熱病 穗稻熱病 水稻 \n\n稻熱病 穗稻熱病 亞賜圃 嘉賜黴素 護粒三賽唑 水稻    3.0
# 2943    1.000000  稻熱病 穗稻熱病 水稻 \n\n稻熱病 穗稻熱病 葉稻熱病 節稻熱病 嘉賜三賽唑 保米熱斯 ...   3.0
# ...          ...                                                ...   ...
# 289443  1.000000  果實蠅 含毒甲基丁香油 \n\n東方果實蠅 瓜實蠅 果實蠅 芬殺松 酵母球 賜諾殺 含毒甲基...   2.0
# 289560  1.000000                       果實蠅 含毒甲基丁香油 \n\n果實蠅 含毒甲基丁香油    2.0
# 289563  1.000000                       果實蠅 含毒甲基丁香油 \n\n果實蠅 含毒甲基丁香油    2.0
# 289572  1.000000  果實蠅 含毒甲基丁香油 \n\n東方果實蠅 果實蠅 含毒甲基丁香油 含毒蛋白質水解物 果樹 ...   2.0
# 289615  1.000000                 果實蠅 含毒甲基丁香油 \n\n東方果實蠅 果實蠅 含毒甲基丁香油    2.0
# 289796  1.000000  果實蠅 含毒甲基丁香油 \n\n斜紋夜蛾 東方果實蠅 瓜實蠅 果實蠅 夜蛾類 性費洛蒙 蘇力...   2.0
# 290001  1.000000  果實蠅 含毒甲基丁香油 \n\n東方果實蠅 瓜實蠅 果實蠅 芬殺松 酵母球 賜諾殺 含毒甲基...   2.0
# 290118  1.000000                       果實蠅 含毒甲基丁香油 \n\n果實蠅 含毒甲基丁香油    2.0
# 290121  1.000000                       果實蠅 含毒甲基丁香油 \n\n果實蠅 含毒甲基丁香油    2.0
# 290130  1.000000  果實蠅 含毒甲基丁香油 \n\n東方果實蠅 果實蠅 含毒甲基丁香油 含毒蛋白質水解物 果樹 ...   2.0
# 290678  1.000000                       果實蠅 含毒甲基丁香油 \n\n果實蠅 含毒甲基丁香油    2.0
# 290679  1.000000                       果實蠅 含毒甲基丁香油 \n\n果實蠅 含毒甲基丁香油    2.0
# 290688  1.000000  果實蠅 含毒甲基丁香油 \n\n東方果實蠅 果實蠅 含毒甲基丁香油 含毒蛋白質水解物 果樹 ...   2.0
# 296223  1.000000  稻熱病 葉稻熱病 嘉賜三賽唑 護粒三賽唑 保米熱斯 富米熱斯 加普胺 克熱賜圃 水稻 \n\...   9.0
# 296232  1.000000  稻熱病 葉稻熱病 嘉賜三賽唑 護粒三賽唑 保米熱斯 富米熱斯 加普胺 克熱賜圃 水稻 \n\...   9.0
# 299446  0.875000  瘤野螟 第滅寧 賽洛寧 培丹 矽護芬 得芬諾 水稻 雜草 \n\n瘤野螟 第滅寧 賽洛寧 培...   8.0
# 299625  0.750000  瘤野螟 第滅寧 賽洛寧 培丹 矽護芬 得芬諾 水稻 雜草 \n\n瘤野螟 賽洛寧 培丹 布芬...   8.0
# 300129  1.000000  稻熱病 葉稻熱病 嘉賜三賽唑 護粒三賽唑 保米熱斯 富米熱斯 加普胺 克熱賜圃 水稻 \n\...   9.0
# 300138  1.000000  稻熱病 葉稻熱病 嘉賜三賽唑 護粒三賽唑 保米熱斯 富米熱斯 加普胺 克熱賜圃 水稻 \n\...   9.0
# 301645  1.000000                            白葉枯病 水稻 \n\n白葉枯病 水稻 雜草    2.0
# 301656  1.000000    白葉枯病 水稻 \n\n白葉枯病 紋枯病 鏈四環黴素 克枯爛 福多寧 菲克利 維利黴素 水稻    2.0
# 302031  0.600000                 薊馬 小黃薊馬 芬普尼 克凡派 檬果 \n\n薊馬 小黃薊馬 檬果    5.0
# 304732  0.857143  果實蠅 含毒甲基丁香油 荔枝 果樹 楊桃 檬果 番石榴 \n\n東方果實蠅 果實蠅 賜諾殺 ...   7.0
# 307943  0.600000  紋枯病 待克利 賓克隆 福多寧 菲克利 維利黴素 貝芬同 賓得克利 達滅淨 水稻 \n\n白...  10.0
# 308567  0.833333  紋枯病 維利黴素 賓得克利 達滅淨 水稻 雜草 \n\n紋枯病 待克利 賓克隆 福多寧 菲克...   6.0
# 309701  1.000000                            稻熱病 水稻 \n\n稻熱病 葉稻熱病 水稻    2.0
# 309705  1.000000                            稻熱病 水稻 \n\n稻熱病 葉稻熱病 水稻    2.0
# 310034  1.000000          稻熱病 水稻 \n\n稻熱病 葉稻熱病 三賽唑 保米熱斯 滅大松 嘉賜貝芬 水稻    2.0
# 310040  1.000000           稻熱病 水稻 \n\n稻熱病 穗稻熱病 葉稻熱病 三賽唑 加普胺 滅大松 水稻    2.0
# 310147  1.000000         稻熱病 水稻 \n\n稻熱病 穗稻熱病 三賽唑 嘉賜三賽唑 保米熱斯 加普胺 水稻    2.0
#
# [395 rows x 10 columns]

# %%
df_sim.loc[(df_sim['pred']==0) & (df_sim['labeled']==1)]
# Out:
#                 Keys  pred   cos_sim   dif  labeled  cos_sim_w2v   dif_w2v  \
# 41362   [1186, 1176]     0  0.912871   1.0        1     0.972401  1.007135
# 46389   [1199, 1187]     0  0.845154   2.0        1     0.949417  0.442744
# 55314   [1243, 1180]     0  0.384900  -6.0        1     0.752889 -0.709361
# 74325   [1320, 1267]     0  0.912871   1.0        1     0.973002  0.873410
# 81540   [1340, 1180]     0  0.384900  -6.0        1     0.752889 -0.709361
# 83214   [1347, 1180]     0  0.596285  -4.0        1     0.909982  0.003117
# 93352   [1392, 1391]     0  0.824958   1.0        1     0.977282 -0.217497
# 106496    [185, 819]     0  0.500000  -3.0        1     0.829241  0.266831
# 113183    [219, 800]     0  0.316228 -18.0        1     0.699380 -1.279212
# 131932    [297, 307]     0  0.646762  -8.0        1     0.914704 -2.574895
# 170686    [465, 857]     0  0.447214  -4.0        1     0.663744 -4.149330
# 171819     [471, 89]     0  0.577350   1.0        1     0.838302 -1.844445
# 181490   [510, 1331]     0  0.436436  -4.0        1     0.669497  5.886994
# 181580    [510, 286]     0  0.462910 -11.0        1     0.627723  6.371133
# 181843    [510, 851]     0  0.365148  -7.0        1     0.573137  7.326250
# 191880    [556, 838]     0  0.424437 -26.0        1     0.829877  2.780364
# 192697    [562, 181]     0  0.496139  -8.0        1     0.882001 -1.074758
# 192822    [562, 478]     0  0.596285  -4.0        1     0.861429 -0.211594
# 192876    [562, 609]     0  0.390360 -16.0        1     0.741081  0.367397
# 195342   [576, 1119]     0  0.534522 -11.0        1     0.870923 -0.916806
# 195707    [576, 680]     0  0.585540  -8.0        1     0.887551 -0.740585
# 197947    [586, 694]     0  0.760639  -4.0        1     0.950270 -0.834025
# 219140    [659, 678]     0  0.912871  -1.0        1     0.975500  1.976134
# 234772    [700, 690]     0  0.866025   1.0        1     0.942804  0.942829
# 263890    [809, 891]     0  0.534522  -5.0        1     0.760197 -2.236060
# 293251    [911, 457]     0  0.612372  -2.0        1     0.891653 -0.983751
# 293295    [911, 562]     0  0.894427  -1.0        1     0.947433  1.719112
# 293489     [911, 95]     0  0.707107   2.0        1     0.829332 -2.759818
# 304097    [961, 967]     0  0.654654  -4.0        1     0.822588  1.390990
# 309404    [986, 375]     0  0.597614   3.0        1     0.903554  0.045948
# 309444    [986, 478]     0  0.527046   1.0        1     0.883009  1.552911
# 309448     [986, 49]     0  0.597614   3.0        1     0.903554  0.045948
# 309503    [986, 616]     0  0.632456   1.0        1     0.939781 -0.321474
# 309517    [986, 646]     0  0.600000   0.0        1     0.931105  0.574768
# 309577    [986, 759]     0  0.597614   3.0        1     0.903554  0.045948
# 309596    [986, 790]     0  0.597614   3.0        1     0.903554  0.045948
# 310216    [988, 913]     0  0.500000  -6.0        1     0.747126 -3.582824
#
#            group                                               sent   min
# 41362   0.833333      花薊馬 第滅寧 陶斯松 滅大松 香蕉 雜草 \n\n花薊馬 第滅寧 陶斯松 滅大松 香蕉    6.0
# 46389   0.714286  黑星病 葉斑病 鋅錳乃浦 滅大松 礦物油 普克利 香蕉 \n\n鋅錳乃浦 滅大松 礦物油 普...   7.0
# 55314   0.666667  黑星病 鋅錳乃浦 香蕉 \n\n黑星病 鋅錳乃浦 待克利 亞托敏 滅大松 礦物油 普克利 環...   3.0
# 74325   0.833333      花薊馬 水銹斑 第滅寧 陶斯松 香蕉 雜草 \n\n花薊馬 水銹斑 第滅寧 陶斯松 香蕉    6.0
# 81540   0.666667  黑星病 鋅錳乃浦 香蕉 \n\n黑星病 鋅錳乃浦 待克利 亞托敏 滅大松 礦物油 普克利 環...   3.0
# 83214   0.800000  黑星病 鋅錳乃浦 待克利 亞托敏 香蕉 \n\n黑星病 鋅錳乃浦 待克利 亞托敏 滅大松 礦...   5.0
# 93352   0.777778  疫病 炭疽病 果腐病 褐腐病 凡殺克絕 亞托待克利 賽座滅 克熱淨(烷苯磺酸鹽) 蓮霧 \n...   9.0
# 106496  1.000000                        斜紋夜蛾 \n\n斜紋夜蛾 甜菜夜蛾 瓜實蠅 夜蛾類    1.0
# 113183  1.000000  晚疫病 番茄 \n\n晚疫病 灰黴病 菌核病 水稻 西瓜 蔬菜 蓮霧 果樹 木瓜 番茄 馬鈴...   2.0
# 131932  0.888889  炭疽病 鋅錳乃浦 甲基多保淨 免得爛 得克利 撲克拉錳 荔枝 果樹 番荔枝 \n\n炭疽病 ...   9.0
# 170686  1.000000                           梨木蝨 \n\n梨木蝨 木蝨 赤星病 梨 龍柏    1.0
# 171819  0.500000                       瘤野螟 賽洛寧 培丹 水稻 \n\n瘤野螟 螟蟲 水稻    4.0
# 181490  0.666667       白葉枯病 水稻 雜草 \n\n褐飛蝨 白背飛蝨 斑飛蝨 白葉枯病 煤煙病 飛蝨類 水稻    3.0
# 181580  1.000000  白葉枯病 水稻 雜草 \n\n炭疽病 潰瘍病 稻熱病 白葉枯病 果疫病 水稻 香蕉 果樹 番...   3.0
# 181843  0.666667  白葉枯病 水稻 雜草 \n\n斜紋夜蛾 軟腐病 疫病 炭疽病 潰瘍病 白葉枯病 滅大松 水稻...   3.0
# 191880  0.875000  水稻水象鼻蟲 象鼻蟲 加保扶 培丹 免扶克 丁基加保扶 水稻 雜草 \n\n薊馬 葉稻熱病 ...   8.0
# 192697  0.800000  白葉枯病 鏈四環黴素 克枯爛 滅大松 水稻 \n\n疫病 炭疽病 白葉枯病 福壽螺 鏈四環黴...   5.0
# 192822  0.800000  白葉枯病 鏈四環黴素 克枯爛 滅大松 水稻 \n\n白葉枯病 胡麻葉枯病 鋅錳乃浦 撲殺熱 ...   5.0
# 192876  0.800000  白葉枯病 鏈四環黴素 克枯爛 滅大松 水稻 \n\n疫病 瘤野螟 褐飛蝨 白葉枯病 晚疫病 ...   5.0
# 195342  0.857143  稻熱病 穗稻熱病 葉稻熱病 三賽唑 加普胺 滅大松 水稻 \n\n稻熱病 白葉枯病 穗稻熱病...   7.0
# 195707  0.857143  稻熱病 穗稻熱病 葉稻熱病 三賽唑 加普胺 滅大松 水稻 \n\n稻熱病 穗稻熱病 葉稻熱病...   7.0
# 197947  0.900000  瘤野螟 白葉枯病 撲殺熱 賽洛寧 鏈四環黴素 克枯爛 毆殺松 得芬諾 水稻 雜草 \n\n瘤...  10.0
# 219140  1.000000  薊馬 小黃薊馬 賽洛寧 益達胺 丁基加保扶 \n\n薊馬 小黃薊馬 賽洛寧 益達胺 丁基加保...   5.0
# 234772  0.750000                        薊馬 蚜蟲 洋香瓜 雜草 \n\n薊馬 蚜蟲 洋香瓜    4.0
# 263890  1.000000       稻熱病 穗稻熱病 \n\n褐飛蝨 斑飛蝨 稻熱病 穗稻熱病 水稻縞葉枯病 毒素病 水稻    2.0
# 293251  0.750000   白葉枯病 鏈四環黴素 克枯爛 水稻 \n\n白葉枯病 紋枯病 鏈四環黴素 賽氟滅 依普座 水稻    4.0
# 293295  1.000000       白葉枯病 鏈四環黴素 克枯爛 水稻 \n\n白葉枯病 鏈四環黴素 克枯爛 滅大松 水稻    4.0
# 293489  0.500000                     白葉枯病 鏈四環黴素 克枯爛 水稻 \n\n白葉枯病 水稻    4.0
# 304097  1.000000    果實蠅 含毒甲基丁香油 果樹 \n\n果實蠅 含毒甲基丁香油 荔枝 果樹 楊桃 檬果 番石榴    3.0
# 309404  0.500000  白葉枯病 三賽唑 撲殺熱 陶斯松 鏈四環黴素 克枯爛 賓克隆 鐵甲砷酸銨 毆殺松 水稻 \n...  10.0
# 309444  0.500000  白葉枯病 三賽唑 撲殺熱 陶斯松 鏈四環黴素 克枯爛 賓克隆 鐵甲砷酸銨 毆殺松 水稻 \n...  10.0
# 309448  0.500000  白葉枯病 三賽唑 撲殺熱 陶斯松 鏈四環黴素 克枯爛 賓克隆 鐵甲砷酸銨 毆殺松 水稻 \n...  10.0
# 309503  0.600000  白葉枯病 三賽唑 撲殺熱 陶斯松 鏈四環黴素 克枯爛 賓克隆 鐵甲砷酸銨 毆殺松 水稻 \n...  10.0
# 309517  0.600000  白葉枯病 三賽唑 撲殺熱 陶斯松 鏈四環黴素 克枯爛 賓克隆 鐵甲砷酸銨 毆殺松 水稻 \n...  10.0
# 309577  0.500000  白葉枯病 三賽唑 撲殺熱 陶斯松 鏈四環黴素 克枯爛 賓克隆 鐵甲砷酸銨 毆殺松 水稻 \n...  10.0
# 309596  0.500000  白葉枯病 三賽唑 撲殺熱 陶斯松 鏈四環黴素 克枯爛 賓克隆 鐵甲砷酸銨 毆殺松 水稻 \n...  10.0
# 310216  1.000000  稻熱病 水稻 \n\n稻熱病 水稻水象鼻蟲 胡麻葉枯病 徒長病 苗立枯病 線蟲白尖病 根瘤線...   2.0

# %%
mypath="./dataPublicComplete/"
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

public_pre = pd.read_csv('Public_data.csv')
paras1 = [re.sub("\'| |\[|\]", '', text).split(',') for text in public_pre['text']]

comps=[]
ordering=[]
for i in onlyfiles:
    ordering.append(np.int(i[:-4]))
for i in ordering:
    for j in ordering:
        if i!=j:
            comps.append([i,j])

Word_freq_all=[]
Word_freq_sent_all=[]
Word_freq_all_w2v=[]
lens=[]
for par_ in paras1:
    word_count=np.zeros(len(Names))
    word_count_sent=''
    w2v=np.zeros(vz)
    
    for i in range(len(Names)):
        if Names[i] in par_:
            for j in range(count_times(par_,Names[i],True)):
                word_count+=one_hot(i,len(Names))
                word_count_sent+=(Names[i]+' ')
                w2v+=model_w2v.wv[Names[i]]
    Word_freq_all.append(word_count)
    Word_freq_sent_all.append(word_count_sent)
    Word_freq_all_w2v.append(w2v/np.sum(word_count))
    lens.append(np.sum(word_count))
    
    
df = pd.read_csv ('TrainLabel.csv',header=None)
labels=[]
for i in range(len(df.iloc[:][0])-1):
    i+=1
    labels.append([np.int(df.iloc[i][0]),np.int(df.iloc[i][1])])
    
Word_freq_all=np.array(Word_freq_all)
data=Word_freq_all
data_w2v=Word_freq_all_w2v

similarity=[]
diff=[]
similarity_w2v=[]
diff_w2v=[]
group=[]
len_diff=[]
senten=[]
mins=[]

for i in range(data.shape[0]):
    sim=[]
    dif=[]
    
    sim_w2v=[]
    dif_w2v=[]
    gp=[]
    len_dif=[]
    sent=[]
    minn=[]
    for j in range(data.shape[0]):
        if i!=j:
            if (norm(data[i]) !=0 and norm(data[j])!=0):
                
                cos_sim = dot(data[i], data[j])/(norm(data[i])*norm(data[j]))
                cos_sim_w2v = dot(data_w2v[i], data_w2v[j])/(norm(data_w2v[i])*norm(data_w2v[j]))

                sim.append(cos_sim)
                sim_w2v.append(cos_sim_w2v)
                
                gp.append(dot(data[i], data[j])/np.sum(data[i]))
                dif.append(np.sum(data[i]-data[j]))
                dif_w2v.append(np.sum(data_w2v[i]-data_w2v[j]))
                len_dif.append(lens[i]-lens[j])
                minn.append(lens[i])
            else:
                sim.append(-1)
                sim_w2v.append(-1)
                gp.append(-1)
                dif.append(-1000)
                dif_w2v.append(-1000)
                len_dif.append(-1000)
                minn.append(-1)
            sent.append(Word_freq_sent_all[i]+'\n'+'\n'+Word_freq_sent_all[j])
            
    similarity.append(sim)
    diff.append(dif)
    group.append(gp)
    similarity_w2v.append(sim_w2v)
    diff_w2v.append(dif_w2v)
    len_diff.append(len_dif)
    senten.append(sent)
    mins.append(minn)
# Out:
# C:\Users\Billy\anaconda3\envs\tensorflow_1\lib\site-packages\ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide

# %%
df_sim=pd.DataFrame(data={'Keys':comps,\
                          'cos_sim':np.array(similarity).reshape(-1),\
                          'dif':np.array(diff).reshape(-1),\
                          'cos_sim_w2v':np.array(similarity_w2v).reshape(-1),\
                          'dif_w2v':np.array(diff_w2v).reshape(-1),\
                          'group':np.array(group).reshape(-1),\
                          'sent':np.array(senten).reshape(-1),\
                          'min':np.array(mins).reshape(-1)})


plt.plot(np.array(df_sim['cos_sim']),np.array(df_sim['dif']),'.',alpha=0.3)
plt.xlim([-1.2,1.2])
plt.ylim([-100,100])
plt.xlabel('cos_sim',fontsize=15)
plt.ylabel('dif',fontsize=15)
plt.show()

plt.plot(np.array(df_sim['cos_sim']),np.array(df_sim['cos_sim_w2v']),'.',alpha=0.3)
plt.xlim([-1.2,1.2])
plt.ylim([-1.2,1.2])
plt.xlabel('cos_sim',fontsize=15)
plt.ylabel('cos_sim_w2v',fontsize=15)
plt.show()

plt.plot(np.array(df_sim['dif']),np.array(df_sim['dif_w2v']),'.',alpha=0.3)
plt.xlim([-100,100])
plt.ylim([-30,30])
plt.xlabel('dif',fontsize=15)
plt.ylabel('dif_w2v',fontsize=15)
plt.show()

plt.plot(np.array(df_sim['dif']),np.array(df_sim['group']),'.',alpha=0.3)
plt.xlim([-100,100])
plt.ylim([-1.2,1.2])
plt.xlabel('dif',fontsize=15)
plt.ylabel('group',fontsize=15)
plt.show()


plt.plot(np.array(df_sim['dif']),np.array(df_sim['min']),'.',alpha=0.3)
plt.xlim([-100,100])
plt.ylim([-10,100])
plt.xlabel('dif',fontsize=15)
plt.ylabel('min',fontsize=15)
plt.show()

# %%
df1=df_sim.loc[df_sim['cos_sim'] >0.3]
df2=df1.loc[(df1['dif'] <15) & (-35 < df1['dif'])]
df8=df2.loc[(df2['cos_sim_w2v'] >0.5)]
df9=df8.loc[(df8['dif_w2v'] >-8) & (df8['dif_w2v'] <8)]
df11=df9.loc[(df9['min'] >1) & (df9['min'] <20)]
df3=df11.loc[(df11['group'] >0.8)]


# from sklearn import preprocessing
# scaler = preprocessing.StandardScaler().fit(np.array(df3[['cos_sim','dif','lens','cos_sim_w2v','dif_w2v','group','min']]))
# X_scaled = scaler.transform(np.array(df3[['cos_sim','dif','lens','cos_sim_w2v','dif_w2v','group','min']]))

X_scaled=np.array(df3[['cos_sim','dif','cos_sim_w2v','dif_w2v','group','min']])

# from sklearn.decomposition import PCA
# pca = PCA(n_components=7)
# pca.fit(np.array(df3[['cos_sim','dif','lens','cos_sim_w2v','dif_w2v','group','min']]))
# X_scaled=pca.transform(np.array(df3[['cos_sim','dif','lens','cos_sim_w2v','dif_w2v','group','min']]))


y_pred=(clf.predict_proba(X_scaled)[:,1]> 0.5).astype("int64")

sel=[]
for i in range(len(y_pred)):
    if y_pred[i]==1:
        sel.append(df3.iloc[i,0])
        
print(len(sel))

data = {'Test': np.array(sel)[:,0], 'Reference': np.array(sel)[:,1]}
df = pd.DataFrame(data)
        
mypath="C:/Users/Billy/Desktop/Data mining/Final project/"
os.chdir(mypath)

df.to_csv('select_name_test.csv', index=False)
# Out:
# 669
